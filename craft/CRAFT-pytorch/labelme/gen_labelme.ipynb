# %%
import os

# %%
data_path = '../data/'

image_path = os.listdir(data_path)
image_path
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-9ad63cb5b2c4> in <module>
#       1 data_path = '../data/'
#       2
# ----> 3 image_path = os.listdir(data_path)
#       4 image_path
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/'

# %%
# Out:
# 2
